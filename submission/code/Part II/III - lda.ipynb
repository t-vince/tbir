# %% [markdown]
# # Text-based Information Retrieval
#
# ## Assignment PART II
# ### Using wordembedding
# We can use the semantic similarity of wordembeddings, such as GloVe and Word2Vec, to obtain better results.
# In this part of the exercise, we will the addition analogy (similar to Part I of this assignment) to rank the given documents.

# %%
# Loading modules
import os, re
import pandas as pd
from numpy import dot, sum
#from gensim import matutils, models, corpora, similarities
import gensim

# Set up logger that logs (works in jupyter 3!) in console and outputs in file
'''
import logging
logger = logging.getLogger()
fhandler = logging.FileHandler(filename='part_II_logs.log', mode='a')
formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
fhandler.setFormatter(formatter)
logger.addHandler(fhandler)
logger.setLevel(logging.DEBUG)
'''
# Out:
# "\nimport logging\nlogger = logging.getLogger()\nfhandler = logging.FileHandler(filename='part_II_logs.log', mode='a')\nformatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')\nfhandler.setFormatter(formatter)\nlogger.addHandler(fhandler)\nlogger.setLevel(logging.DEBUG)\n"

# %% [markdown]
# #### Images to wordvectors

# %% [markdown]
# We will use the similarity of wordmodels such as Word2Vec and GloVe to make vectors of each image. These vectors will look like
# >s = w1 + w2 + ... + wn
#
# > With s = the image vector and {w1 .. wn} the words for each image

# %%
# Load in a stopword list from
# http://www.lextek.com/manuals/onix/stopwords2.html
stopwords = []
with open('data/stopwordlist.txt', 'r') as f:
    lines = ''.join(f.readlines())
    stopwords = [x for x in lines.split('\n')[2:]]

# %%
# Clean input because the wordmodels can not contain every possible combination words and signs
def clean_input(text, stopwords):
    # lowecase and remove linebreaks
    text = text.lower().rstrip()
    # Remove stopwords
    text = ' '.join([word for word in text.split() if word not in stopwords])
    # Remove punctuation
    text = re.sub('[!@#$:;%&?,_\.\'\`\"\\\/\(\)\[\]]', '', text)
    text = re.sub('[\-]+', '-', text)
    # Remove sole numbers, dashes or extra spaces
    text = re.sub('[\s][\-]+[\s]', '', text)
    text = re.sub('[0-9]+', '', text)
    text = re.sub('[\s]+', ' ', text)
    # British to American English - at this moment still hardcoded due to lack of library
    text = text.replace('grey', 'gray')
    text = text.replace('colour', 'color')
    text = text.replace('tyre', 'tire')
    text = text.replace('centre', 'center')
    text = text.replace('theatre', 'theater')
    text = text.replace('jewellery','jewelry')
    text = text.replace('aeroplane', 'plane')
    text = text.replace('harbour', 'harbor')
    text = text.replace('moustache','mustache')
    text = text.replace(' axe', ' hatchet')
    text = text.replace('armour', 'armor')
    text = text.replace('stylised', 'stylized')
    text = text.replace('organise', 'organize')
    text = text.replace('plough', 'plow')
    text = text.replace('neighbourhood', 'neighborhood')
    text = text.replace('vapour', 'vapor')
    # some manual fixes of lemmatizing
    text = text.replace('watersid ', 'waterside ')
    text = text.replace('figur ', 'figure ')
    text = text.replace(' graz ', ' graze ')
    text = ' '.join([word for word in text.split() if word not in stopwords])
    return text

# %%
# Text file parser
# Returns a dictionary with imageid - text in lowercase without stopwords or punctuation
def text_file_parser(filename, stopwords):
    corpus = dict()
    #corpus = pd.DataFrame(columns=('id', 'imageid', 'vec'))
    with open(filename) as f:
        # next(f) # skip first line with the headings
        for doc in f:
            # Split on spaces
            doc_parts = doc.split(" ", 1)
            # If first part is the ID (needed for the queries file)
            if(len(doc_parts[0]) < 6):
                doc_parts = doc.split(" ", 2)
                doc_parts.pop(0)
            # Clean the caption text (remove puctuation etc)
            doc_parts[1] = clean_input(doc_parts[1], stopwords)
            # add the array (or row) to an array
            corpus[len(corpus) + 1] = doc_parts        
    # Transform to dataframe
    df = pd.DataFrame.from_dict(corpus, orient='index')
    df = df.reset_index()
    df.columns = ['index', 'img_id', 'caption']
    return df

# %%
# images file to docs dict
print('Parsing documents')
training_docs = text_file_parser('data/target_collection_parsed.txt', stopwords)
docs = []
for text in training_docs['caption']:
    docs.append(text.split())
dictionary = gensim.corpora.Dictionary(docs)
# convert tokenized documents into a document-term matrix
corpus = [dictionary.doc2bow(doc) for doc in docs]   
# generate LDA model
lda = gensim.models.ldamodel.LdaModel(corpus, num_topics=300, id2word = dictionary, passes=10, alpha="auto")
queries = text_file_parser('data/queries_val_parsed.txt', stopwords)

# Preview
queries
# Out:
# Parsing documents
#      index            img_id  \
# 0        1  CbnA_e6AW6U7Ycoa
# 1        2  XBZPztvt67qkMUdI
# 2        3  PaqtOaYmQmXkqW2i
# 3        4  IPcFtNL-7EQ6Z0yu
# 4        5  IMAD0sq2Fz7HpSgX
# 5        6  -gqRDDfPZTGlCfJa
# 6        7  xsrYb57vl4qiMLDG
# 7        8  BCjxgJlQ3TD5T8ST
# 8        9  LGxwsl9CtRQ8wW3Y
# 9       10  9LtOvyiygFYoxU8S
# 10      11  8usTLD-Wg5EHCShk
# 11      12  kH59MJp3nWyFfFB2
# 12      13  tluPF-CA6dN6LACF
# 13      14  HKXYBXXObkt_yi7s
# 14      15  mBJjuuB0ukfKmnRH
# 15      16  cqpTaVCZZe5OpuIk
# 16      17  Anry0qU5NFes6Twh
# 17      18  ByjuNEqsLcbUk5OH
# 18      19  5dBiwoDEpY6gWRek
# 19      20  ZFdHuWXCk662UDAW
# 20      21  BqoajT5F2iTYrBVY
# 21      22  6e3OOBOz0U2yUPw2
# 22      23  fSA2edOk84knSsCd
# 23      24  b1BJi-1w-Rx0TTYR
# 24      25  K4WT0f0TDFUF1oss
# 25      26  RDoxm_sjkO6p-jfU
# 26      27  4U7OnXftrQUXbSwZ
# 27      28  8Yc1fvVrq4t0Jg0g
# 28      29  _-Y9MEwXW1byM5Ia
# 29      30  O5cAfwjvftQzafZ3
# ..     ...               ...
# 970    971  Z1TKwXyWzPHIFyqo
# 971    972  WsHd9WhpLTVCLUlq
# 972    973  JKPdw6y2FTJxsh1K
# 973    974  5-I1KW3scIc4pbsZ
# 974    975  v4My8_bo8z3Xwqxc
# 975    976  FhwdAJ46w3nyp8TX
# 976    977  VH-qvLkwpmbFCwOK
# 977    978  hawj8QzTA-Eil_rD
# 978    979  eQ4lbzbmh7k60mlp
# 979    980  Sh0zz4xg3Y4m3qPv
# 980    981  -dp39Cdz3XJstMoS
# 981    982  HipIEk7-Itnp9PcB
# 982    983  8-FHUXbxYGlRM5LL
# 983    984  BetXL-_TeL926a8t
# 984    985  UqXOPOVpFVKDFJyn
# 985    986  TojsF8C4bNb0UKvQ
# 986    987  -q-lecPJgKXcZnOI
# 987    988  56qZnrVS3CzBG9Rs
# 988    989  fynWgHfhy5sjydX6
# 989    990  yW8dpEWfc3wwO3J6
# 990    991  BCjxgJlQ3TD5T8ST
# 991    992  mMPiMRMAOsllXJX1
# 992    993  -PNOjxOjVGR7tmk7
# 993    994  DYvDr2CFE77pikTb
# 994    995  AtSw6SmdQ2-PdnWL
# 995    996  onL79JCBLbPO5WE6
# 996    997  8k3j8rDXPor6INeN
# 997    998  XxYyaPP_Yno4x935
# 998    999  tliWJPOil1cylMd5
# 999   1000  6xf0y9zkKrEWqMK5
#
#                                                caption
# 0              people group holding award pose picture
# 1    man white shirt sit table cut meat plate front...
# 2                       woman red dress posing hatchet
# 3                  soccer play stand soccer ball front
# 4                             white yellow train track
# 5                              view tall building city
# 6                                hand pick flower vine
# 7                              picture army ready sail
# 8                             brick roof house picture
# 9                                man clean mess street
# 10           group kid play playground accompany adult
# 11      woman black shirt jean pant picture red carpet
# 12                                boat sail body water
# 13            crowd people stadium watch baseball game
# 14                           men drag large snake tail
# 15                           group people street beach
# 16                woman sit bottom bed neat hotel room
# 17                    man wear glove mask destroy wall
# 18             brick entrance building tree background
# 19     woman bright red lipstick sing large microphone
# 20      picture people climb snow-covered mountain day
# 21                                 men woman stand row
# 22                          young girl rid bike street
# 23                           bike stand lock bike rack
# 24                            dog wrong eye teeth miss
# 25                          man young woman pose photo
# 26                                 rocky ruin blue sky
# 27                            men play basketball dunk
# 28                          lady black smile lean wall
# 29                           woman wear glass hold pen
# ..                                                 ...
# 970                             large bowl cook oyster
# 971                  white airplane runway green grass
# 972                 man woman wear fancy attire camera
# 973  blonde woman wear white dress high heel shoe r...
# 974                           rid horse-drawn carriage
# 975                                 blue building sign
# 976                happy couple cuddle couch christmas
# 977                              lady white face paint
# 978                           picture open pack butter
# 979                    festoon horse flower braid mane
# 980  rocket ship launch pad blue sky background tre...
# 981        man brightly color shirt swing front people
# 982                      naked man painting paint body
# 983                                woman put lock bike
# 984                 neat tidy wooden bed standing room
# 985                   man green shirt hold certificate
# 986                                    fish bowl water
# 987                                    machine gym spa
# 988                                    view river tree
# 989    woman long black hair hold gray beard mans face
# 990                            group soldier walk boat
# 991  aerial view circular swimming pool complex mid...
# 992  aerial view long gray ship dock sea-bank beach...
# 993       trio young girl wear pastel t-shirt sit sofa
# 994                                lady large red rose
# 995                                       donkey field
# 996  snow cap mountain background grass cover slope...
# 997                      police offer hold notepad car
# 998                        men woman picture hold flag
# 999             men lean man lie bed people background
#
# [1000 rows x 3 columns]

# %% [markdown]
# #### Check similarity

# %%
tfidf = gensim.models.TfidfModel(corpus)
length = len(dictionary)
sim_index = gensim.similarities.Similarity('./tmp/tst',corpus, num_features=length)
print('querying')

'''
# Calculate similarity
#training_docs["sim"] = 0.0
queries['recall'] = 0.0
queries['precision'] = 0.0
for i,r in queries.iterrows():
    
    # Calculate similarity per vector document
    vec_bow = dictionary.doc2bow(r['caption'].split())
    vec_lda = lda[vec_bow]
    sims = index[vec_lda]
    sims = sorted(enumerate(sims), key=lambda item: -item[1])
    sims = [sim[0] for sim in sims[:1000]]
    
    # Recall
    total_to_find = float(len(training_docs[training_docs.img_id == r['img_id']]))
    correct = 0
    for sim in sims:
        if training_docs[training_docs.index == sim].values[0][1] == r['img_id']:
            correct += 1
    
    amount_found = correct
    recall = float(amount_found/total_to_find)
    queries.set_value(i, 'recall', recall)
    
    # Precision
    precision = float(amount_found/float(1000))
    queries.set_value(i, 'precision', precision)

print('Finished querying')
'''

# Create outputfile if not already exists
#if not os.path.exists(output_file):
#    open(output_file, 'w').close()

# Create a results dataframe that will contain the MAP and average recall for all run queries
results = pd.DataFrame(index=range(0,1000), columns=['map', 'recall'])
results['map'] = 0.0
results['recall'] = 0.0

# Calculate similarity
print ("Calculating precision and recall")
for i,r in queries.iterrows():
    print ("Processing query", i) # Print the current query number
    
    # Calculate similarity per vector document
    vec_bow = dictionary.doc2bow(r['caption'].split())
    vec_lda = lda[vec_bow]
    sims = sim_index[vec_lda]
    
    # order by similarity and get top 1000 results
    sims = sorted(enumerate(sims), key=lambda item: -item[1])
    sims = [sim[0] for sim in sims[:1000]]
    
    # Get total amount of images that should be found
    total_to_find = float(len(training_docs[training_docs.img_id == r['img_id']]))
    total_found = 0.0
    current_avg_precision = 0.0
    
    # Iterare over top 1000 found documents
    for index, sim in enumerate(sims):
        if training_docs[training_docs.index == sim].values[0][1] == r['img_id']:
            total_found += 1.0
            
        # Append values to dataframe for precision-recall curve
        current_avg_precision = float(current_avg_precision) + float(total_found/float(index + 1.0))
        curr_results = results.loc[index]
        results.set_value(index, "recall", float(curr_results['recall']) + float(total_found/total_to_find))
        results.set_value(index, "map", float(curr_results['map']) + float(current_avg_precision/float(index + 1.0)))
        
        # Append to the output file
        #with open(output_file,'a') as f:
        #    # Output in the file is structured as:
        #    # query_id 0 sent_id 0 similarity_score 0
        #    f.write(str(r['index'])+' 0 '+str(row['index'])+' 0 '+str(row['sim'])+" 0\n")
    
# Reduce results rows to averages
results['recall'] = results.apply((lambda row: float(float(row['recall'])/1000.0)), axis=1)
results['map'] = results.apply((lambda row: float(float(row['map'])/1000.0)), axis=1)
# Out:
# querying
# Calculating precision and recall
# Processing query 0
# Processing query 1
# Processing query 2
# Processing query 3
# Processing query 4
# Processing query 5
# Processing query 6
# Processing query 7
# Processing query 8
# Processing query 9
# Processing query 10
# Processing query 11
# Processing query 12
# Processing query 13
# Processing query 14
# Processing query 15
# Processing query 16
# Processing query 17
# Processing query 18
# Processing query 19
# Processing query 20
# Processing query 21
# Processing query 22
# Processing query 23
# Processing query 24
# Processing query 25
# Processing query 26
# Processing query 27
# Processing query 28
# Processing query 29
# Processing query 30
# Processing query 31
# Processing query 32
# Processing query 33
# Processing query 34
# Processing query 35
# Processing query 36
# Processing query 37
# Processing query 38
# Processing query 39
# Processing query 40
# Processing query 41
# Processing query 42
# Processing query 43
# Processing query 44
# Processing query 45
# Processing query 46
# Processing query 47
# Processing query 48
# Processing query 49
# Processing query 50
# Processing query 51
# Processing query 52
# Processing query 53
# Processing query 54
# Processing query 55
# Processing query 56
# Processing query 57
# Processing query 58
# Processing query 59
# Processing query 60
# Processing query 61
# Processing query 62
# Processing query 63
# Processing query 64
# Processing query 65
# Processing query 66
# Processing query 67
# Processing query 68
# Processing query 69
# Processing query 70
# Processing query 71
# Processing query 72
# Processing query 73
# Processing query 74
# Processing query 75
# Processing query 76
# Processing query 77
# Processing query 78
# Processing query 79
# Processing query 80
# Processing query 81
# Processing query 82
# Processing query 83
# Processing query 84
# Processing query 85
# Processing query 86
# Processing query 87
# Processing query 88
# Processing query 89
# Processing query 90
# Processing query 91
# Processing query 92
# Processing query 93
# Processing query 94
# Processing query 95
# Processing query 96
# Processing query 97
# Processing query 98
# Processing query 99
# Processing query 100
# Processing query 101
# Processing query 102
# Processing query 103
# Processing query 104
# Processing query 105
# Processing query 106
# Processing query 107
# Processing query 108
# Processing query 109
# Processing query 110
# Processing query 111
# Processing query 112
# Processing query 113
# Processing query 114
# Processing query 115
# Processing query 116
# Processing query 117
# Processing query 118
# Processing query 119
# Processing query 120
# Processing query 121
# Processing query 122
# Processing query 123
# Processing query 124
# Processing query 125
# Processing query 126
# Processing query 127
# Processing query 128
# Processing query 129
# Processing query 130
# Processing query 131
# Processing query 132
# Processing query 133
# Processing query 134
# Processing query 135
# Processing query 136
# Processing query 137
# Processing query 138
# Processing query 139
# Processing query 140
# Processing query 141
# Processing query 142
# Processing query 143
# Processing query 144
# Processing query 145
# Processing query 146
# Processing query 147
# Processing query 148
# Processing query 149
# Processing query 150
# Processing query 151
# Processing query 152
# Processing query 153
# Processing query 154
# Processing query 155
# Processing query 156
# Processing query 157
# Processing query 158
# Processing query 159
# Processing query 160
# Processing query 161
# Processing query 162
# Processing query 163
# Processing query 164
# Processing query 165
# Processing query 166
# Processing query 167
# Processing query 168
# Processing query 169
# Processing query 170
# Processing query 171
# Processing query 172
# Processing query 173
# Processing query 174
# Processing query 175
# Processing query 176
# Processing query 177
# Processing query 178
# Processing query 179
# Processing query 180
# Processing query 181
# Processing query 182
# Processing query 183
# Processing query 184
# Processing query 185
# Processing query 186
# Processing query 187
# Processing query 188
# Processing query 189
# Processing query 190
# Processing query 191
# Processing query 192
# Processing query 193
# Processing query 194
# Processing query 195
# Processing query 196
# Processing query 197
# Processing query 198
# Processing query 199
# Processing query 200
# Processing query 201
# Processing query 202
# Processing query 203
# Processing query 204
# Processing query 205
# Processing query 206
# Processing query 207
# Processing query 208
# Processing query 209
# Processing query 210
# Processing query 211
# Processing query 212
# Processing query 213
# Processing query 214
# Processing query 215
# Processing query 216
# Processing query 217
# Processing query 218
# Processing query 219
# Processing query 220
# Processing query 221
# Processing query 222
# Processing query 223
# Processing query 224
# Processing query 225
# Processing query 226
# Processing query 227
# Processing query 228
# Processing query 229
# Processing query 230
# Processing query 231
# Processing query 232
# Processing query 233
# Processing query 234
# Processing query 235
# Processing query 236
# Processing query 237
# Processing query 238
# Processing query 239
# Processing query 240
# Processing query 241
# Processing query 242
# Processing query 243
# Processing query 244
# Processing query 245
# Processing query 246
# Processing query 247
# Processing query 248
# Processing query 249
# Processing query 250
# Processing query 251
# Processing query 252
# Processing query 253
# Processing query 254
# Processing query 255
# Processing query 256
# Processing query 257
# Processing query 258
# Processing query 259
# Processing query 260
# Processing query 261
# Processing query 262
# Processing query 263
# Processing query 264
# Processing query 265
# Processing query 266
# Processing query 267
# Processing query 268
# Processing query 269
# Processing query 270
# Processing query 271
# Processing query 272
# Processing query 273
# Processing query 274
# Processing query 275
# Processing query 276
# Processing query 277
# Processing query 278
# Processing query 279
# Processing query 280
# Processing query 281
# Processing query 282
# Processing query 283
# Processing query 284
# Processing query 285
# Processing query 286
# Processing query 287
# Processing query 288
# Processing query 289
# Processing query 290
# Processing query 291
# Processing query 292
# Processing query 293
# Processing query 294
# Processing query 295
# Processing query 296
# Processing query 297
# Processing query 298
# Processing query 299
# Processing query 300
# Processing query 301
# Processing query 302
# Processing query 303
# Processing query 304
# Processing query 305
# Processing query 306
# Processing query 307
# Processing query 308
# Processing query 309
# Processing query 310
# Processing query 311
# Processing query 312
# Processing query 313
# Processing query 314
# Processing query 315
# Processing query 316
# Processing query 317
# Processing query 318
# Processing query 319
# Processing query 320
# Processing query 321
# Processing query 322
# Processing query 323
# Processing query 324
# Processing query 325
# Processing query 326
# Processing query 327
# Processing query 328
# Processing query 329
# Processing query 330
# Processing query 331
# Processing query 332
# Processing query 333
# Processing query 334
# Processing query 335
# Processing query 336
# Processing query 337
# Processing query 338
# Processing query 339
# Processing query 340
# Processing query 341
# Processing query 342
# Processing query 343
# Processing query 344
# Processing query 345
# Processing query 346
# Processing query 347
# Processing query 348
# Processing query 349
# Processing query 350
# Processing query 351
# Processing query 352
# Processing query 353
# Processing query 354
# Processing query 355
# Processing query 356
# Processing query 357
# Processing query 358
# Processing query 359
# Processing query 360
# Processing query 361
# Processing query 362
# Processing query 363
# Processing query 364
# Processing query 365
# Processing query 366
# Processing query 367
# Processing query 368
# Processing query 369
# Processing query 370
# Processing query 371
# Processing query 372
# Processing query 373
# Processing query 374
# Processing query 375
# Processing query 376
# Processing query 377
# Processing query 378
# Processing query 379
# Processing query 380
# Processing query 381
# Processing query 382
# Processing query 383
# Processing query 384
# Processing query 385
# Processing query 386
# Processing query 387
# Processing query 388
# Processing query 389
# Processing query 390
# Processing query 391
# Processing query 392
# Processing query 393
# Processing query 394
# Processing query 395
# Processing query 396
# Processing query 397
# Processing query 398
# Processing query 399
# Processing query 400
# Processing query 401
# Processing query 402
# Processing query 403
# Processing query 404
# Processing query 405
# Processing query 406
# Processing query 407
# Processing query 408
# Processing query 409
# Processing query 410
# Processing query 411
# Processing query 412
# Processing query 413
# Processing query 414
# Processing query 415
# Processing query 416
# Processing query 417
# Processing query 418
# Processing query 419
# Processing query 420
# Processing query 421
# Processing query 422
# Processing query 423
# Processing query 424
# Processing query 425
# Processing query 426
# Processing query 427
# Processing query 428
# Processing query 429
# Processing query 430
# Processing query 431
# Processing query 432
# Processing query 433
# Processing query 434
# Processing query 435
# Processing query 436
# Processing query 437
# Processing query 438
# Processing query 439
# Processing query 440
# Processing query 441
# Processing query 442
# Processing query 443
# Processing query 444
# Processing query 445
# Processing query 446
# Processing query 447
# Processing query 448
# Processing query 449
# Processing query 450
# Processing query 451
# Processing query 452
# Processing query 453
# Processing query 454
# Processing query 455
# Processing query 456
# Processing query 457
# Processing query 458
# Processing query 459
# Processing query 460
# Processing query 461
# Processing query 462
# Processing query 463
# Processing query 464
# Processing query 465
# Processing query 466
# Processing query 467
# Processing query 468
# Processing query 469
# Processing query 470
# Processing query 471
# Processing query 472
# Processing query 473
# Processing query 474
# Processing query 475
# Processing query 476
# Processing query 477
# Processing query 478
# Processing query 479
# Processing query 480
# Processing query 481
# Processing query 482
# Processing query 483
# Processing query 484
# Processing query 485
# Processing query 486
# Processing query 487
# Processing query 488
# Processing query 489
# Processing query 490
# Processing query 491
# Processing query 492
# Processing query 493
# Processing query 494
# Processing query 495
# Processing query 496
# Processing query 497
# Processing query 498
# Processing query 499
# Processing query 500
# Processing query 501
# Processing query 502
# Processing query 503
# Processing query 504
# Processing query 505
# Processing query 506
# Processing query 507
# Processing query 508
# Processing query 509
# Processing query 510
# Processing query 511
# Processing query 512
# Processing query 513
# Processing query 514
# Processing query 515
# Processing query 516
# Processing query 517
# Processing query 518
# Processing query 519
# Processing query 520
# Processing query 521
# Processing query 522
# Processing query 523
# Processing query 524
# Processing query 525
# Processing query 526
# Processing query 527
# Processing query 528
# Processing query 529
# Processing query 530
# Processing query 531
# Processing query 532
# Processing query 533
# Processing query 534
# Processing query 535
# Processing query 536
# Processing query 537
# Processing query 538
# Processing query 539
# Processing query 540
# Processing query 541
# Processing query 542
# Processing query 543
# Processing query 544
# Processing query 545
# Processing query 546
# Processing query 547
# Processing query 548
# Processing query 549
# Processing query 550
# Processing query 551
# Processing query 552
# Processing query 553
# Processing query 554
# Processing query 555
# Processing query 556
# Processing query 557
# Processing query 558
# Processing query 559
# Processing query 560
# Processing query 561
# Processing query 562
# Processing query 563
# Processing query 564
# Processing query 565
# Processing query 566
# Processing query 567
# Processing query 568
# Processing query 569
# Processing query 570
# Processing query 571
# Processing query 572
# Processing query 573
# Processing query 574
# Processing query 575
# Processing query 576
# Processing query 577
# Processing query 578
# Processing query 579
# Processing query 580
# Processing query 581
# Processing query 582
# Processing query 583
# Processing query 584
# Processing query 585
# Processing query 586
# Processing query 587
# Processing query 588
# Processing query 589
# Processing query 590
# Processing query 591
# Processing query 592
# Processing query 593
# Processing query 594
# Processing query 595
# Processing query 596
# Processing query 597
# Processing query 598
# Processing query 599
# Processing query 600
# Processing query 601
# Processing query 602
# Processing query 603
# Processing query 604
# Processing query 605
# Processing query 606
# Processing query 607
# Processing query 608
# Processing query 609
# Processing query 610
# Processing query 611
# Processing query 612
# Processing query 613
# Processing query 614
# Processing query 615
# Processing query 616
# Processing query 617
# Processing query 618
# Processing query 619
# Processing query 620
# Processing query 621
# Processing query 622
# Processing query 623
# Processing query 624
# Processing query 625
# Processing query 626
# Processing query 627
# Processing query 628
# Processing query 629
# Processing query 630
# Processing query 631
# Processing query 632
# Processing query 633
# Processing query 634
# Processing query 635
# Processing query 636
# Processing query 637
# Processing query 638
# Processing query 639
# Processing query 640
# Processing query 641
# Processing query 642
# Processing query 643
# Processing query 644
# Processing query 645
# Processing query 646
# Processing query 647
# Processing query 648
# Processing query 649
# Processing query 650
# Processing query 651
# Processing query 652
# Processing query 653
# Processing query 654
# Processing query 655
# Processing query 656
# Processing query 657
# Processing query 658
# Processing query 659
# Processing query 660
# Processing query 661
# Processing query 662
# Processing query 663
# Processing query 664
# Processing query 665
# Processing query 666
# Processing query 667
# Processing query 668
# Processing query 669
# Processing query 670
# Processing query 671
# Processing query 672
# Processing query 673
# Processing query 674
# Processing query 675
# Processing query 676
# Processing query 677
# Processing query 678
# Processing query 679
# Processing query 680
# Processing query 681
# Processing query 682
# Processing query 683
# Processing query 684
# Processing query 685
# Processing query 686
# Processing query 687
# Processing query 688
# Processing query 689
# Processing query 690
# Processing query 691
# Processing query 692
# Processing query 693
# Processing query 694
# Processing query 695
# Processing query 696
# Processing query 697
# Processing query 698
# Processing query 699
# Processing query 700
# Processing query 701
# Processing query 702
# Processing query 703
# Processing query 704
# Processing query 705
# Processing query 706
# Processing query 707
# Processing query 708
# Processing query 709
# Processing query 710
# Processing query 711
# Processing query 712
# Processing query 713
# Processing query 714
# Processing query 715
# Processing query 716
# Processing query 717
# Processing query 718
# Processing query 719
# Processing query 720
# Processing query 721
# Processing query 722
# Processing query 723
# Processing query 724
# Processing query 725
# Processing query 726
# Processing query 727
# Processing query 728
# Processing query 729
# Processing query 730
# Processing query 731
# Processing query 732
# Processing query 733
# Processing query 734
# Processing query 735
# Processing query 736
# Processing query 737
# Processing query 738
# Processing query 739
# Processing query 740
# Processing query 741
# Processing query 742
# Processing query 743
# Processing query 744
# Processing query 745
# Processing query 746
# Processing query 747
# Processing query 748
# Processing query 749
# Processing query 750
# Processing query 751
# Processing query 752
# Processing query 753
# Processing query 754
# Processing query 755
# Processing query 756
# Processing query 757
# Processing query 758
# Processing query 759
# Processing query 760
# Processing query 761
# Processing query 762
# Processing query 763
# Processing query 764
# Processing query 765
# Processing query 766
# Processing query 767
# Processing query 768
# Processing query 769
# Processing query 770
# Processing query 771
# Processing query 772
# Processing query 773
# Processing query 774
# Processing query 775
# Processing query 776
# Processing query 777
# Processing query 778
# Processing query 779
# Processing query 780
# Processing query 781
# Processing query 782
# Processing query 783
# Processing query 784
# Processing query 785
# Processing query 786
# Processing query 787
# Processing query 788
# Processing query 789
# Processing query 790
# Processing query 791
# Processing query 792
# Processing query 793
# Processing query 794
# Processing query 795
# Processing query 796
# Processing query 797
# Processing query 798
# Processing query 799
# Processing query 800
# Processing query 801
# Processing query 802
# Processing query 803
# Processing query 804
# Processing query 805
# Processing query 806
# Processing query 807
# Processing query 808
# Processing query 809
# Processing query 810
# Processing query 811
# Processing query 812
# Processing query 813
# Processing query 814
# Processing query 815
# Processing query 816
# Processing query 817
# Processing query 818
# Processing query 819
# Processing query 820
# Processing query 821
# Processing query 822
# Processing query 823
# Processing query 824
# Processing query 825
# Processing query 826
# Processing query 827
# Processing query 828
# Processing query 829
# Processing query 830
# Processing query 831
# Processing query 832
# Processing query 833
# Processing query 834
# Processing query 835
# Processing query 836
# Processing query 837
# Processing query 838
# Processing query 839
# Processing query 840
# Processing query 841
# Processing query 842
# Processing query 843
# Processing query 844
# Processing query 845
# Processing query 846
# Processing query 847
# Processing query 848
# Processing query 849
# Processing query 850
# Processing query 851
# Processing query 852
# Processing query 853
# Processing query 854
# Processing query 855
# Processing query 856
# Processing query 857
# Processing query 858
# Processing query 859
# Processing query 860
# Processing query 861
# Processing query 862
# Processing query 863
# Processing query 864
# Processing query 865
# Processing query 866
# Processing query 867
# Processing query 868
# Processing query 869
# Processing query 870
# Processing query 871
# Processing query 872
# Processing query 873
# Processing query 874
# Processing query 875
# Processing query 876
# Processing query 877
# Processing query 878
# Processing query 879
# Processing query 880
# Processing query 881
# Processing query 882
# Processing query 883
# Processing query 884
# Processing query 885
# Processing query 886
# Processing query 887
# Processing query 888
# Processing query 889
# Processing query 890
# Processing query 891
# Processing query 892
# Processing query 893
# Processing query 894
# Processing query 895
# Processing query 896
# Processing query 897
# Processing query 898
# Processing query 899
# Processing query 900
# Processing query 901
# Processing query 902
# Processing query 903
# Processing query 904
# Processing query 905
# Processing query 906
# Processing query 907
# Processing query 908
# Processing query 909
# Processing query 910
# Processing query 911
# Processing query 912
# Processing query 913
# Processing query 914
# Processing query 915
# Processing query 916
# Processing query 917
# Processing query 918
# Processing query 919
# Processing query 920
# Processing query 921
# Processing query 922
# Processing query 923
# Processing query 924
# Processing query 925
# Processing query 926
# Processing query 927
# Processing query 928
# Processing query 929
# Processing query 930
# Processing query 931
# Processing query 932
# Processing query 933
# Processing query 934
# Processing query 935
# Processing query 936
# Processing query 937
# Processing query 938
# Processing query 939
# Processing query 940
# Processing query 941
# Processing query 942
# Processing query 943
# Processing query 944
# Processing query 945
# Processing query 946
# Processing query 947
# Processing query 948
# Processing query 949
# Processing query 950
# Processing query 951
# Processing query 952
# Processing query 953
# Processing query 954
# Processing query 955
# Processing query 956
# Processing query 957
# Processing query 958
# Processing query 959
# Processing query 960
# Processing query 961
# Processing query 962
# Processing query 963
# Processing query 964
# Processing query 965
# Processing query 966
# Processing query 967
# Processing query 968
# Processing query 969
# Processing query 970
# Processing query 971
# Processing query 972
# Processing query 973
# Processing query 974
# Processing query 975
# Processing query 976
# Processing query 977
# Processing query 978
# Processing query 979
# Processing query 980
# Processing query 981
# Processing query 982
# Processing query 983
# Processing query 984
# Processing query 985
# Processing query 986
# Processing query 987
# Processing query 988
# Processing query 989
# Processing query 990
# Processing query 991
# Processing query 992
# Processing query 993
# Processing query 994
# Processing query 995
# Processing query 996
# Processing query 997
# Processing query 998
# Processing query 999

# %% [markdown]
# #### Results

# %%
print ("Displaying results:")

print ("--")
print ("MAP for best 10:", results.loc[9]['map'])
print ("MAP for best 100:", results.loc[99]['map'])
print ("MAP for best 250:", results.loc[249]['map'])
print ("MAP for best 500:", results.loc[499]['map'])
print ("MAP for best 1000:", results.loc[999]['map'])

print ("AVG recall for best 10", results.loc[9]['recall'])
print ("AVG recall for best 100", results.loc[99]['recall'])
print ("AVG recall for best 250", results.loc[249]['recall'])
print ("AVG recall for best 500", results.loc[499]['recall'])
print ("AVG recall for best 1000", results.loc[999]['recall'])
print ("--")

# print results
print (results)
# Out:
# Displaying results:
# --
# MAP for best 10: 0.000874404761905
# MAP for best 100: 0.00127835271594
# MAP for best 250: 0.00117450441248
# MAP for best 500: 0.00112939321511
# MAP for best 1000: 0.00106944473165
# AVG recall for best 10 0.00115810086811
# AVG recall for best 100 0.0110988061106
# AVG recall for best 250 0.0228248133427
# AVG recall for best 500 0.0451026322661
# AVG recall for best 1000 0.0788785285645
# --
#           map    recall
# 0    0.000000  0.000000
# 1    0.000000  0.000000
# 2    0.000111  0.000022
# 3    0.000333  0.000312
# 4    0.000467  0.000412
# 5    0.000583  0.000464
# 6    0.000684  0.000676
# 7    0.000739  0.000676
# 8    0.000805  0.000869
# 9    0.000874  0.001158
# 10   0.000927  0.001301
# 11   0.000968  0.001412
# 12   0.001000  0.001483
# 13   0.001031  0.001775
# 14   0.001060  0.001947
# 15   0.001091  0.002313
# 16   0.001117  0.002413
# 17   0.001141  0.002538
# 18   0.001159  0.002538
# 19   0.001171  0.002538
# 20   0.001185  0.002991
# 21   0.001200  0.003300
# 22   0.001210  0.003300
# 23   0.001217  0.003300
# 24   0.001224  0.003438
# 25   0.001229  0.003438
# 26   0.001231  0.003438
# 27   0.001235  0.003589
# 28   0.001237  0.003614
# 29   0.001240  0.003747
# ..        ...       ...
# 970  0.001073  0.076820
# 971  0.001073  0.076945
# 972  0.001073  0.076945
# 973  0.001073  0.076969
# 974  0.001073  0.076969
# 975  0.001072  0.076969
# 976  0.001072  0.077045
# 977  0.001072  0.077045
# 978  0.001072  0.077045
# 979  0.001072  0.077045
# 980  0.001072  0.077386
# 981  0.001072  0.077463
# 982  0.001072  0.077463
# 983  0.001071  0.077463
# 984  0.001071  0.077777
# 985  0.001071  0.077977
# 986  0.001071  0.077977
# 987  0.001071  0.077977
# 988  0.001071  0.078139
# 989  0.001071  0.078139
# 990  0.001071  0.078139
# 991  0.001070  0.078188
# 992  0.001070  0.078188
# 993  0.001070  0.078565
# 994  0.001070  0.078689
# 995  0.001070  0.078689
# 996  0.001070  0.078689
# 997  0.001070  0.078689
# 998  0.001070  0.078689
# 999  0.001069  0.078879
#
# [1000 rows x 2 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# Sort by recall
#df = df.sort_values(by=['recall'], ascending=[1])

# Show and save chart
qx = results.plot(x='recall', y='map')
#qx.set_xlim([0,1])
#qx.set_ylim([0,1])
fig = qx.get_figure()
fig.savefig('results/part2_lda_precision-recall.png')

# %% [markdown]
# ### Results from calculations on server
# For lowering the workload on our computers, we let a server do the calculations and write the results to a csv file.

# %%
# Read in results file
results = pd.DataFrame.from_csv('results/results.csv')

# averages
print "--"
print "AVG recall", results.recall.mean()
print "AVG precision:",  results.precision.mean()
print "--"

# Preview dataframe
results
